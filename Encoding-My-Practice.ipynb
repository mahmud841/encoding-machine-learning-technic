# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('supershops.csv')
df.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83
# 1        162597.70       151377.59  443898.53      Ctg  191792.06
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39
# 3        144372.41       118671.85  383199.62    Dhaka  182901.99
# 4        142107.34        91391.77  366168.42  Rangpur  166187.94

# %%
# checking null value
# df.isnull()
df.isnull().sum()
# Out:
# Marketing Spend    0
# Administration     0
# Transport          1
# Area               0
# Profit             0
# dtype: int64

# %%
#df

# %%
df.Transport.mean()
# Out:
# 215331.7324489796

# %%
df.Transport.median()
# Out:
# 214634.81

# %%
df.Transport.min()
# Out:
# 0.0

# %%
df.Transport.max()
# Out:
# 471784.1

# %% [raw]
# #  outlayer baire thakle median use korbo r outlayer vitore thakle mean use korbo

# %%
tr_mean = df.Transport.mean()
tr_mean
# Out:
# 215331.7324489796

# %%
df.Transport = df.Transport.fillna( df.Transport.mean())
df.isnull().sum()
# Out:
# Marketing Spend    0
# Administration     0
# Transport          0
# Area               0
# Profit             0
# dtype: int64

# %%
df
# Out:
#     Marketing Spend  Administration      Transport     Area     Profit
# 0         114523.61       136897.80  471784.100000    Dhaka  192261.83
# 1         162597.70       151377.59  443898.530000      Ctg  191792.06
# 2         153441.51       101145.55  407934.540000  Rangpur  191050.39
# 3         144372.41       118671.85  383199.620000    Dhaka  182901.99
# 4         142107.34        91391.77  366168.420000  Rangpur  166187.94
# 5         131876.90        99814.71  362861.360000    Dhaka  156991.12
# 6         134615.46       147198.87  127716.820000      Ctg  156122.51
# 7         130298.13       145530.06  323876.680000  Rangpur  155752.60
# 8         120542.52       148718.95  311613.290000    Dhaka  152211.77
# 9         123334.88       108679.17  304981.620000      Ctg  149759.96
# 10        101913.08       110594.11  229160.950000  Rangpur  146121.95
# 11        100671.96        91790.61  249744.550000      Ctg  144259.40
# ...

# %%
df[18:21]
# Out:
#     Marketing Spend  Administration      Transport     Area     Profit
# 18         91749.16       114175.79  294919.570000  Rangpur  124266.90
# 19         86419.70       153514.11  215331.732449    Dhaka  122776.86
# 20         76253.86       113867.30  298664.470000      Ctg  118474.03

# %%
df2 = df.copy()
df3 = df.copy()
df4 = df.copy()
df5 = df.copy()
df6 = df.copy()
df7 = df.copy()
df8 = df.copy()
df9 = df.copy()
df10 = df.copy()
df11 = df.copy()
df12 = df.copy()

# %%
df.Area.nunique()
# Out:
# 3

# %%
df.Area.value_counts()
# Out:
# Dhaka      17
# Ctg        17
# Rangpur    16
# Name: Area, dtype: int64

# %%
df.Area = df.Area.replace(['Dhaka', 'Ctg', 'Rangpur'], [3,2,1])
df.head()
# Out:
#    Marketing Spend  Administration  Transport  Area     Profit
# 0        114523.61       136897.80  471784.10     3  192261.83
# 1        162597.70       151377.59  443898.53     2  191792.06
# 2        153441.51       101145.55  407934.54     1  191050.39
# 3        144372.41       118671.85  383199.62     3  182901.99
# 4        142107.34        91391.77  366168.42     1  166187.94

# %%
df2.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83
# 1        162597.70       151377.59  443898.53      Ctg  191792.06
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39
# 3        144372.41       118671.85  383199.62    Dhaka  182901.99
# 4        142107.34        91391.77  366168.42  Rangpur  166187.94

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Marketing Spend  50 non-null     float64
#  1   Administration   50 non-null     float64
#  2   Transport        50 non-null     float64
#  3   Area             50 non-null     object
#  4   Profit           50 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 2.1+ KB

# %% [markdown]
# # Label Encoding

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
df2.Area = le.fit_transform(df2.Area)

# %%
df2.head()
# Out:
#    Marketing Spend  Administration  Transport  Area     Profit
# 0        114523.61       136897.80  471784.10     1  192261.83
# 1        162597.70       151377.59  443898.53     0  191792.06
# 2        153441.51       101145.55  407934.54     2  191050.39
# 3        144372.41       118671.85  383199.62     1  182901.99
# 4        142107.34        91391.77  366168.42     2  166187.94

# %%
df3.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83
# 1        162597.70       151377.59  443898.53      Ctg  191792.06
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39
# 3        144372.41       118671.85  383199.62    Dhaka  182901.99
# 4        142107.34        91391.77  366168.42  Rangpur  166187.94

# %%
df3.columns
# Out:
# Index(['Marketing Spend', 'Administration', 'Transport', 'Area', 'Profit'], dtype='object')

# %%
for col in df3.columns:
    if df3[col].dtype == np.number:
        continue
    df3[col] = le.fit_transform(df3[col])
# Out:
# C:\Users\Mahmud\AppData\Local\Temp\ipykernel_1324\163548614.py:2: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
#   if df3[col].dtype == np.number:
# C:\Users\Mahmud\AppData\Local\Temp\ipykernel_1324\163548614.py:2: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
#   if df3[col].dtype == np.number:

# %%
df3.head()
# Out:
#    Marketing Spend  Administration  Transport  Area     Profit
# 0        114523.61       136897.80  471784.10     1  192261.83
# 1        162597.70       151377.59  443898.53     0  191792.06
# 2        153441.51       101145.55  407934.54     2  191050.39
# 3        144372.41       118671.85  383199.62     1  182901.99
# 4        142107.34        91391.77  366168.42     2  166187.94

# %%
df4.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83
# 1        162597.70       151377.59  443898.53      Ctg  191792.06
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39
# 3        144372.41       118671.85  383199.62    Dhaka  182901.99
# 4        142107.34        91391.77  366168.42  Rangpur  166187.94

# %%
for col in df4.columns:
    if df4[col].dtype == np.number:
        continue
    df4[col] = le.fit_transform(df4[col])
# Out:
# C:\Users\Mahmud\AppData\Local\Temp\ipykernel_1324\1508553752.py:2: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
#   if df4[col].dtype == np.number:
# C:\Users\Mahmud\AppData\Local\Temp\ipykernel_1324\1508553752.py:2: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
#   if df4[col].dtype == np.number:

# %%
df4.head()
# Out:
#    Marketing Spend  Administration  Transport  Area     Profit
# 0        114523.61       136897.80  471784.10     1  192261.83
# 1        162597.70       151377.59  443898.53     0  191792.06
# 2        153441.51       101145.55  407934.54     2  191050.39
# 3        144372.41       118671.85  383199.62     1  182901.99
# 4        142107.34        91391.77  366168.42     2  166187.94
